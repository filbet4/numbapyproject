# %% [markdown]
# # numbapy demo
#
# This notebook demonstrates installing the package and running a tiny Numba-accelerated computation.
# - Colab: run the install cell (edit the repo URL placeholders).

# %%
# Colab install option A (after publishing):
# %pip install numbapy

# Colab install option B (from GitHub):
# %pip install git+https://github.com/filbet4/numbapyproject.git

# For Binder, the project is already available; no install needed.
pass

# %%
import numpy as np
from numbapy import sum_of_squares

x = np.arange(100_000, dtype=np.float64)
result = sum_of_squares(x)
result
